# %% [markdown]
# <a href="https://colab.research.google.com/github/andreaafs100766/Histograma/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip3 install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np

excel_file = '/Cópia de Planilha MODELO - Copia.xlsm'
f = pd.ExcelFile(excel_file)

list_of_dfs = []

for sheet in f.sheet_names:
    df = f.parse(sheet)
    list_of_dfs.append(df)

list_of_dfs
# Out:
# [                               ResourceId                 ResourceName  \
#  0    6e32a473-189c-ed11-9bcf-00155d88fd6b      BOMBA DE AGUA ATE 10 CV
#  1    8df3987d-189c-ed11-8238-00155d883321  BOMBA DE AGUA DE 11 A 25 CV
#  2    052ec490-189c-ed11-a630-00155d887f6c         BOMBA DE CONCRETO CP
#  3    e1049798-189c-ed11-a630-00155d887f6c         BOMBA DE CONCRETO TK
#  4    7b620d9f-189c-ed11-ac8c-00155d88f279         BOMBA DE ESGOTAMENTO
#  ..                                    ...                          ...
#  240  5e42cddb-1a9c-ed11-8238-00155d883321           UNIDADE HIDRAULICA
#  241  6d42cddb-1a9c-ed11-8238-00155d883321                          VAN
#  242  2d79d7ed-1a9c-ed11-b033-00155d883d7d                  VEICULO 4X4
#  243  03fc1af3-1a9c-ed11-a7b6-00155d88fd6d                 VEICULO LEVE
#  244  6441c8f7-1a9c-ed11-8436-00155d88fc80               VEICULO PICKUP
#
#       ResourceType  Histograma  Nivelamento
#  0               2        True          NaN
# ...
